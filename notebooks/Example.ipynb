# %%
# Hacky
import sys
sys.path.append('../.')

from progan_layers import custom_objects
from keras.models import load_model

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
progan = load_model('../weights/keras_progan.hdf5', custom_objects=custom_objects)
# Out:
# /usr/local/lib/python3.5/dist-packages/keras/engine/saving.py:269: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
latents = np.random.RandomState(1000).randn(1000, 512) # 1000 random latents
latents = latents[[477, 56]] # hand-picked top-10

imgs = progan.predict(latents)
# Predicts in range -1 to 1
imgs = (imgs + 1) / 2
imgs = np.clip(imgs, 0, 1)

# %%
plt.imshow(imgs[0])
plt.axis('off')
plt.savefig('example.png')

# %%
# Compare to the example images provided the authors repo.
